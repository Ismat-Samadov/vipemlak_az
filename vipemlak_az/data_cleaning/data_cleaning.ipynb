# %%
import pandas as pd

# %%
data=pd.read_csv(r'main.csv')

# %%
data
# Out:
#                                                     link   phone_number
# 0      https://vipemlak.az/nesimi-rayonu-dede-qorqud-...  (055) 2052361
# 1          https://vipemlak.az/28may-metrosu-604456.html  (070) 6738658
# 2      https://vipemlak.az/xetai-rayonu-8-noyabr-pr.-...  (051) 2292595
# 3      https://vipemlak.az/s.behlulzade-kucesi-604481...  (055) 2127071
# 4      https://vipemlak.az/metal-qebulu-demir-alisi-5...  (077) 3063628
# ...                                                  ...            ...
# 29397  https://vipemlak.az/yasamal-rayonu-hesen-bey-z...  (055) 2008465
# 29398  https://vipemlak.az/behruz-nuriyev-kucesi-5674...  (055) 6511177
# 29399  https://vipemlak.az/xetai-rayonu-ag-seher-5674...  (077) 9090060
# 29400    https://vipemlak.az/cavadxan-kucesi-567423.html  (055) 3573363
# 29401  https://vipemlak.az/n.nerimanov-r-nu-eliyar-el...  (070) 8140200
#
# [29402 rows x 2 columns]

# %%
data['phone_number_cleaned'] = data['phone_number'].str.replace(r'\D', '', regex=True)

# %%
data
# Out:
#                                                     link   phone_number  \
# 0      https://vipemlak.az/nesimi-rayonu-dede-qorqud-...  (055) 2052361
# 1          https://vipemlak.az/28may-metrosu-604456.html  (070) 6738658
# 2      https://vipemlak.az/xetai-rayonu-8-noyabr-pr.-...  (051) 2292595
# 3      https://vipemlak.az/s.behlulzade-kucesi-604481...  (055) 2127071
# 4      https://vipemlak.az/metal-qebulu-demir-alisi-5...  (077) 3063628
# ...                                                  ...            ...
# 29397  https://vipemlak.az/yasamal-rayonu-hesen-bey-z...  (055) 2008465
# 29398  https://vipemlak.az/behruz-nuriyev-kucesi-5674...  (055) 6511177
# 29399  https://vipemlak.az/xetai-rayonu-ag-seher-5674...  (077) 9090060
# 29400    https://vipemlak.az/cavadxan-kucesi-567423.html  (055) 3573363
# 29401  https://vipemlak.az/n.nerimanov-r-nu-eliyar-el...  (070) 8140200
#
#       phone_number_cleaned
# 0               0552052361
# 1               0706738658
# ...

# %%
data.to_excel('data.xlsx', index=False)
